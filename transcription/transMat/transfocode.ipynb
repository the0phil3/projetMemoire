# %%
import xml.etree.ElementTree as ET
import pandas as pd
import csv
from bs4 import BeautifulSoup

# %%
xmlfile = "archives_CAPM_E0017_1918_950_A8863-A9654-0001.xml"

# %%
tree = ET.parse(xmlfile)
root = tree.getroot()

# %%
ET.dump(tree)
# Out:
# <ns0:alto xmlns:ns0="http://www.loc.gov/standards/alto/ns-v4#" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.loc.gov/standards/alto/ns-v4# http://www.loc.gov/standards/alto/v4/alto-4-2.xsd">
#   <ns0:Description>
#     <ns0:MeasurementUnit>pixel</ns0:MeasurementUnit>
#     <ns0:sourceImageInformation>
#       <ns0:fileName>archives_CAPM_E0017_1918_950_A8863-A9654-0001.jpeg</ns0:fileName>
#
#     </ns0:sourceImageInformation>
#   </ns0:Description>
#
#   <ns0:Tags>
#           <ns0:OtherTag ID="BT3545" LABEL="corps_d'affectation" DESCRIPTION="block type corps_d'affectation" />
#           <ns0:OtherTag ID="BT3544" LABEL="matricule_id" DESCRIPTION="block type matricule_id" />
#           <ns0:OtherTag ID="BT3543" LABEL="engagement" DESCRIPTION="block type engagement" />
#           <ns0:OtherTag ID="BT3542" LABEL="etat_civil" DESCRIPTION="block type etat_civil" />
#           <ns0:OtherTag ID="BT3541" LABEL="noms" DESCRIPTION="block type noms" />
# ...

# %%
for elm in root.findall(".//Description"):
    print(elm.tag, elm.attrib)

# %%
infile = open("archives_CAPM_E0017_1918_950_A8863-A9654-0001.xml","r")
contents = infile.read()
soup = BeautifulSoup(contents,'xml')

# %%
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <alto xmlns="http://www.loc.gov/standards/alto/ns-v4#" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.loc.gov/standards/alto/ns-v4# http://www.loc.gov/standards/alto/v4/alto-4-2.xsd">
# <Description>
# <MeasurementUnit>pixel</MeasurementUnit>
# <sourceImageInformation>
# <fileName>archives_CAPM_E0017_1918_950_A8863-A9654-0001.jpeg</fileName>
# </sourceImageInformation>
# </Description>
# <Tags>
# <OtherTag DESCRIPTION="block type corps_d'affectation" ID="BT3545" LABEL="corps_d'affectation"/>
# <OtherTag DESCRIPTION="block type matricule_id" ID="BT3544" LABEL="matricule_id"/>
# <OtherTag DESCRIPTION="block type engagement" ID="BT3543" LABEL="engagement"/>
# <OtherTag DESCRIPTION="block type etat_civil" ID="BT3542" LABEL="etat_civil"/>
# <OtherTag DESCRIPTION="block type noms" ID="BT3541" LABEL="noms"/>
# <OtherTag DESCRIPTION="line type historique" ID="LT1220" LABEL="historique"/>
# ...

# %%
text=soup.String["CONTENT"]

# %%
shit = soup.find_all('String')

# %%
shit
# Out:
# [<String CONTENT="O. Daredj" HEIGHT="156" HPOS="857" VPOS="453" WIDTH="288"/>,
#  <String CONTENT="0. Salah Mohamed" HEIGHT="126" HPOS="872" VPOS="2133" WIDTH="301"/>,
#  <String CONTENT="Abdesselem" HEIGHT="174" HPOS="238" VPOS="153" WIDTH="616"/>,
#  <String CONTENT="ben Zarouel" HEIGHT="108" HPOS="278" VPOS="290" WIDTH="362"/>,
#  <String CONTENT="A 8863" HEIGHT="171" HPOS="1948" VPOS="125" WIDTH="263"/>,
#  <String CONTENT="presume en 1893" HEIGHT="126" HPOS="217" VPOS="492" WIDTH="453"/>,
#  <String CONTENT="61eme Regiment de T. Ma-" HEIGHT="144" HPOS="1611" VPOS="985" WIDTH="658"/>,
#  <String CONTENT="13 fevrier 1918 pour 4 ans" HEIGHT="129" HPOS="309" VPOS="1322" WIDTH="876"/>,
#  <String CONTENT="Decede le 8 juillet 1921 a Seroux des" HEIGHT="135" HPOS="1258" VPOS="1111" WIDTH="1039"/>,
#  <String CONTENT="suites de maladie contractee en service" HEIGHT="95" HPOS="1252" VPOS="1215" WIDTH="1002"/>,
#  <String CONTENT="Maati" HEIGHT="101" HPOS="257" VPOS="1879" WIDTH="805"/>,
# ...

# %%
for i in range(0,len(shit)):
    print(soup.get[i].get)
# Out:
# <bound method PageElement.get_text of <String CONTENT="O. Daredj" HEIGHT="156" HPOS="857" VPOS="453" WIDTH="288"/>>
# <bound method PageElement.get_text of <String CONTENT="0. Salah Mohamed" HEIGHT="126" HPOS="872" VPOS="2133" WIDTH="301"/>>
# <bound method PageElement.get_text of <String CONTENT="Abdesselem" HEIGHT="174" HPOS="238" VPOS="153" WIDTH="616"/>>
# <bound method PageElement.get_text of <String CONTENT="ben Zarouel" HEIGHT="108" HPOS="278" VPOS="290" WIDTH="362"/>>
# <bound method PageElement.get_text of <String CONTENT="A 8863" HEIGHT="171" HPOS="1948" VPOS="125" WIDTH="263"/>>
# <bound method PageElement.get_text of <String CONTENT="presume en 1893" HEIGHT="126" HPOS="217" VPOS="492" WIDTH="453"/>>
# <bound method PageElement.get_text of <String CONTENT="61eme Regiment de T. Ma-" HEIGHT="144" HPOS="1611" VPOS="985" WIDTH="658"/>>
# <bound method PageElement.get_text of <String CONTENT="13 fevrier 1918 pour 4 ans" HEIGHT="129" HPOS="309" VPOS="1322" WIDTH="876"/>>
# ...
