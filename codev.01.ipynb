# %% [markdown]
# ## This is my practice code for scrapping

# %%
import requests, os, pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
#Practice 1
url = "https://en.wikipedia.org/wiki/Everyman_(novel)"
#Ca ne marche pas pour le site memoire des hommes du SHD. Il est illisibles par requests.
info = requests.get(url)

if info.ok:
    print(info.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Everyman (novel) - Wikipedia</title>
# ...

# %%
#Practice 2
driver = webdriver.Chrome("/Users/Theo/Dev/scrappingProject/chromedriver")

driver.get("https://www.memoiredeshommes.sga.defense.gouv.fr/fr/arkotheque/client/mdh/opex_1905_1962/")
# Out:
# <ipython-input-34-3a173b026b08>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/Users/Theo/Dev/scrappingProject/chromedriver")
