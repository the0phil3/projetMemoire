# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import os, glob

# %%
cd ~/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/
# Out:
# /Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs

# %%
# Making a loop statement to create all the dataframes from the csv files
path = "/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/"
all_files = glob.glob(path + "*.csv")

# %%
all_files
# Out:
# ['/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_a.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_v.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_w.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_b.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_u.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_t.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_c.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_p.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_g.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_f.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_q.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_s.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_d.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_e.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_r.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_h.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_i.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_k.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_j.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_n.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_y.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_x.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_o.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_m.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_z.csv',
#  '/Users/Theo/dev/projetMemoire/militaires-decedes-sur-les-theatres-d-operations-exterieurs/Fond_10a_base_nominative_l.csv']

# %%
li = [pd.read_csv(filename, encoding='UTF-8', engine="python", sep = ";") for filename in all_files]
db = pd.concat(li, axis = 0, ignore_index = True)

# %%
db
# Out:
#                     id_conflit_intitule id_sous_conflit_intitule  \
# 0      Théâtres d'opérations extérieurs          Afrique du Nord
# 1      Théâtres d'opérations extérieurs                   Levant
# 2      Théâtres d'opérations extérieurs                   Levant
# 3      Théâtres d'opérations extérieurs          Afrique du Nord
# 4      Théâtres d'opérations extérieurs          Afrique du Nord
# ...                                 ...                      ...
# 20054  Théâtres d'opérations extérieurs          Afrique du Nord
# 20055  Théâtres d'opérations extérieurs                   Levant
# 20056  Théâtres d'opérations extérieurs          Afrique du Nord
# 20057  Théâtres d'opérations extérieurs          Afrique du Nord
# 20058  Théâtres d'opérations extérieurs                   Levant
#
#       id_famille_cote_intitule  sous_serie serie  article  \
# 0                          NaN         NaN   NaN      NaN
# 1                           AC        40.0     R   4063.0
# 2                           AC        40.0     R   4063.0
# 3                           AC        40.0     R   4034.0
# 4                           AC        40.0     R   4034.0
# ...                        ...         ...   ...      ...
# 20054                      NaN         NaN   NaN      NaN
# 20055                       AC        40.0     R   4070.0
# 20056                       AC        40.0     R   4046.0
# 20057                       AC        40.0     R   4046.0
# 20058                       AC        40.0     R   4070.0
#
#                                       nom      prenom nom_autre pseudonyme  \
# 0      AB EL OUAHAB BEN SAID BEN BELGACEM         NaN       NaN        NaN
# 1                                  ABABOA         NaN       NaN        NaN
# 2                                  ABABOU  Abdelkader       NaN        NaN
# 3                                  ABABSA    Belgacem       NaN        NaN
# 4               ABABSIA OTHMANE BEN AHMED         NaN       NaN        NaN
# ...                                   ...         ...       ...        ...
# 20054                               LUZET         NaN       NaN        NaN
# 20055                               LVOFF       André       NaN        NaN
# 20056                  LYARID BEN FARRADJ         NaN       NaN        NaN
# 20057                LYAZID BEL FKI AOMAR         NaN       NaN        NaN
# 20058                               LYSRI      Youcef       NaN        NaN
#
#        ... disparition_date_libre disparition_jour_mois_annee  \
# 0      ...                    NaN                         NaN
# 1      ...                    NaN                         NaN
# 2      ...                    NaN                         NaN
# 3      ...                    NaN                         NaN
# 4      ...                    NaN                         NaN
# ...    ...                    ...                         ...
# 20054  ...                    NaN                         NaN
# 20055  ...                    NaN                         NaN
# 20056  ...                    NaN                         NaN
# 20057  ...                    NaN                         NaN
# 20058  ...                    NaN                         NaN
#
#       jdd_jour_mois_annee disparition_lieu_complement  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
# ...                   ...                         ...
# 20054                 NaN                         NaN
# 20055                 NaN                         NaN
# 20056                 NaN                         NaN
# 20057                 NaN                         NaN
# 20058                 NaN                         NaN
#
#       id_disparition_lieu_intitule id_disparition_departement_intitule  \
# 0                              NaN                                 NaN
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
# ...                            ...                                 ...
# 20054                          NaN                                 NaN
# 20055                          NaN                                 NaN
# 20056                          NaN                                 NaN
# 20057                          NaN                                 NaN
# 20058                          NaN                                 NaN
#
#        id_disparition_pays_intitule id_tgi_lieu_intitule  \
# 0                               NaN                  NaN
# 1                               NaN                  NaN
# 2                               NaN                  NaN
# 3                               NaN                  NaN
# 4                               NaN                  NaN
# ...                             ...                  ...
# 20054                           NaN                  NaN
# 20055                           NaN                  NaN
# 20056                           NaN                  NaN
# 20057                           NaN                  NaN
# 20058                           NaN                  NaN
#
#       id_tgi_departement_intitule id_tgi_pays_intitule
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN
# ...                           ...                  ...
# 20054                         NaN                  NaN
# 20055                         NaN                  NaN
# 20056                         NaN                  NaN
# 20057                         NaN                  NaN
# 20058                         NaN                  NaN
#
# [20059 rows x 74 columns]

# %%
clean1db = db.dropna(axis=1, how="all", thresh=None, subset=None, inplace=False)

# %%
clean1db.columns
# Out:
# Index(['id_conflit_intitule', 'id_sous_conflit_intitule',
#        'id_famille_cote_intitule', 'sous_serie', 'serie', 'article', 'nom',
#        'prenom', 'nom_autre', 'pseudonyme', 'naissance_jour_mois_annee',
#        'id_naissance_lieu_intitule', 'id_naissance_departement_intitule',
#        'id_naissance_pays_intitule', 'id_statut_intitule',
#        'id_mention_intitule', 'classe', 'recrutement_matricule',
#        'id_recrutement_bureau_intitule', 'id_grade_intitule',
#        'id_unite_intitule', 'id_bataillon_intitule', 'id_compagnie_intitule',
#        'id_batterie_intitule', 'detail_unite', 'id_profession_intitule',
#        'deces_jour_mois_annee', 'id_deces_lieu_intitule',
#        'id_deces_departement_intitule', 'id_deces_pays_intitule',
#        'id_operation_intitule', 'id_transcription_etablissement_lieu_intitule',
#        'id_transcription_etablissement_departement_intitule',
#        'id_transcription_etablissement_pays_intitule',
#        'id_dernier_domicile_lieu_intitule',
#        'id_dernier_domicile_departement_intitule',
#        'id_dernier_domicile_pays_intitule', 'id_sepulture_lieu_intitule',
#        'id_sepulture_departement_intitule', 'id_sepulture_pays_intitule',
#        'id_sepulture_nom_du_site_intitule', 'id_sepulture_type_intitule',
#        'sepulture_tombe_individuelle_numero', 'sources', 'deportation',
#        'decoration_posthume', 'rehabilitation', 'lien_ark_fiche',
#        'corps_retrouve', 'disparition_jour_mois_annee', 'jdd_jour_mois_annee'],
#       dtype='object')

# %%
unwantedcol = ['pseudonyme','id_batterie_intitule','id_compagnie_intitule','id_dernier_domicile_lieu_intitule',
               'id_dernier_domicile_departement_intitule','id_dernier_domicile_pays_intitule','id_sepulture_lieu_intitule',
       'id_sepulture_departement_intitule', 'id_sepulture_pays_intitule',
       'id_sepulture_nom_du_site_intitule', 'id_sepulture_type_intitule',
       'sepulture_tombe_individuelle_numero']

# %%
clean1db.drop(unwantedcol,axis=1)
# Out:
#                     id_conflit_intitule id_sous_conflit_intitule  \
# 0      Théâtres d'opérations extérieurs          Afrique du Nord
# 1      Théâtres d'opérations extérieurs                   Levant
# 2      Théâtres d'opérations extérieurs                   Levant
# 3      Théâtres d'opérations extérieurs          Afrique du Nord
# 4      Théâtres d'opérations extérieurs          Afrique du Nord
# ...                                 ...                      ...
# 20054  Théâtres d'opérations extérieurs          Afrique du Nord
# 20055  Théâtres d'opérations extérieurs                   Levant
# 20056  Théâtres d'opérations extérieurs          Afrique du Nord
# 20057  Théâtres d'opérations extérieurs          Afrique du Nord
# 20058  Théâtres d'opérations extérieurs                   Levant
#
#       id_famille_cote_intitule  sous_serie serie  article  \
# 0                          NaN         NaN   NaN      NaN
# 1                           AC        40.0     R   4063.0
# 2                           AC        40.0     R   4063.0
# 3                           AC        40.0     R   4034.0
# 4                           AC        40.0     R   4034.0
# ...                        ...         ...   ...      ...
# 20054                      NaN         NaN   NaN      NaN
# 20055                       AC        40.0     R   4070.0
# 20056                       AC        40.0     R   4046.0
# 20057                       AC        40.0     R   4046.0
# 20058                       AC        40.0     R   4070.0
#
#                                       nom      prenom nom_autre  \
# 0      AB EL OUAHAB BEN SAID BEN BELGACEM         NaN       NaN
# 1                                  ABABOA         NaN       NaN
# 2                                  ABABOU  Abdelkader       NaN
# 3                                  ABABSA    Belgacem       NaN
# 4               ABABSIA OTHMANE BEN AHMED         NaN       NaN
# ...                                   ...         ...       ...
# 20054                               LUZET         NaN       NaN
# 20055                               LVOFF       André       NaN
# 20056                  LYARID BEN FARRADJ         NaN       NaN
# 20057                LYAZID BEL FKI AOMAR         NaN       NaN
# 20058                               LYSRI      Youcef       NaN
#
#       naissance_jour_mois_annee  ...  \
# 0                    0000-00-00  ...
# 1                           NaN  ...
# 2                           NaN  ...
# 3                           NaN  ...
# 4                           NaN  ...
# ...                         ...  ...
# 20054                       NaN  ...
# 20055                1899-00-00  ...
# 20056                       NaN  ...
# 20057                       NaN  ...
# 20058                       NaN  ...
#
#       id_transcription_etablissement_departement_intitule  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20054                                                NaN
# 20055                              75 - Paris (ex Seine)
# 20056                                                NaN
# 20057                                                NaN
# 20058                                                NaN
#
#       id_transcription_etablissement_pays_intitule  \
# 0                                              NaN
# 1                                          Algérie
# 2                                          Algérie
# 3                                          Algérie
# 4                                          Algérie
# ...                                            ...
# 20054                                          NaN
# 20055                                          NaN
# 20056                                          NaN
# 20057                                          NaN
# 20058                                      Algérie
#
#                                       sources deportation decoration_posthume  \
# 0      Service historique de la Défense, Caen           0                   0
# 1      Service historique de la Défense, Caen           0                   0
# 2      Service historique de la Défense, Caen           0                   0
# 3      Service historique de la Défense, Caen           0                   0
# 4      Service historique de la Défense, Caen           0                   0
# ...                                       ...         ...                 ...
# 20054  Service historique de la Défense, Caen           0                   0
# 20055  Service historique de la Défense, Caen           0                   0
# 20056  Service historique de la Défense, Caen           0                   0
# 20057  Service historique de la Défense, Caen           0                   0
# 20058  Service historique de la Défense, Caen           0                   0
#
#        rehabilitation                                     lien_ark_fiche  \
# 0                   0  https://www.memoiredeshommes.sga.defense.gouv....
# 1                   0  https://www.memoiredeshommes.sga.defense.gouv....
# 2                   0  https://www.memoiredeshommes.sga.defense.gouv....
# 3                   0  https://www.memoiredeshommes.sga.defense.gouv....
# 4                   0  https://www.memoiredeshommes.sga.defense.gouv....
# ...               ...                                                ...
# 20054               0  https://www.memoiredeshommes.sga.defense.gouv....
# 20055               0  https://www.memoiredeshommes.sga.defense.gouv....
# 20056               0  https://www.memoiredeshommes.sga.defense.gouv....
# 20057               0  https://www.memoiredeshommes.sga.defense.gouv....
# 20058               0  https://www.memoiredeshommes.sga.defense.gouv....
#
#       corps_retrouve disparition_jour_mois_annee jdd_jour_mois_annee
# 0                  0                         NaN                 NaN
# 1                  0                         NaN                 NaN
# 2                  0                         NaN                 NaN
# 3                  0                         NaN                 NaN
# 4                  0                         NaN                 NaN
# ...              ...                         ...                 ...
# 20054              0                         NaN                 NaN
# 20055              0                         NaN                 NaN
# 20056              0                         NaN                 NaN
# 20057              0                         NaN                 NaN
# 20058              0                         NaN                 NaN
#
# [20059 rows x 39 columns]

# %%
clean2db = clean1db.__getitem__(clean1db.id_deces_pays_intitule.isin(["Maroc"]))

# %%
clean2db
# Out:
#                     id_conflit_intitule id_sous_conflit_intitule  \
# 0      Théâtres d'opérations extérieurs          Afrique du Nord
# 3      Théâtres d'opérations extérieurs          Afrique du Nord
# 4      Théâtres d'opérations extérieurs          Afrique du Nord
# 5      Théâtres d'opérations extérieurs          Afrique du Nord
# 6      Théâtres d'opérations extérieurs          Afrique du Nord
# ...                                 ...                      ...
# 20052  Théâtres d'opérations extérieurs          Afrique du Nord
# 20053  Théâtres d'opérations extérieurs          Afrique du Nord
# 20054  Théâtres d'opérations extérieurs          Afrique du Nord
# 20056  Théâtres d'opérations extérieurs          Afrique du Nord
# 20057  Théâtres d'opérations extérieurs          Afrique du Nord
#
#       id_famille_cote_intitule  sous_serie serie  article  \
# 0                          NaN         NaN   NaN      NaN
# 3                           AC        40.0     R   4034.0
# 4                           AC        40.0     R   4034.0
# 5                          NaN         NaN   NaN      NaN
# 6                           AC        40.0     R   4034.0
# ...                        ...         ...   ...      ...
# 20052                       AC        40.0     R   4046.0
# 20053                       AC        40.0     R   4046.0
# 20054                      NaN         NaN   NaN      NaN
# 20056                       AC        40.0     R   4046.0
# 20057                       AC        40.0     R   4046.0
#
#                                       nom    prenom nom_autre pseudonyme  ...  \
# 0      AB EL OUAHAB BEN SAID BEN BELGACEM       NaN       NaN        NaN  ...
# 3                                  ABABSA  Belgacem       NaN        NaN  ...
# 4               ABABSIA OTHMANE BEN AHMED       NaN       NaN        NaN  ...
# 5                                ABACHKIN     Arata       NaN        NaN  ...
# 6                                    ABAD     Tayeb       NaN        NaN  ...
# ...                                   ...       ...       ...        ...  ...
# 20052                              LUSTIG   Wilhelm       NaN        NaN  ...
# 20053                         LUXEMBURGER      Jean       NaN        NaN  ...
# 20054                               LUZET       NaN       NaN        NaN  ...
# 20056                  LYARID BEN FARRADJ       NaN       NaN        NaN  ...
# 20057                LYAZID BEL FKI AOMAR       NaN       NaN        NaN  ...
#
#       id_sepulture_type_intitule sepulture_tombe_individuelle_numero  \
# 0                            NaN                                 NaN
# 3                            NaN                                 NaN
# 4                            NaN                                 NaN
# 5                            NaN                                 NaN
# 6                            NaN                                 NaN
# ...                          ...                                 ...
# 20052                        NaN                                 NaN
# 20053                        NaN                                 NaN
# 20054                        NaN                                 NaN
# 20056                        NaN                                 NaN
# 20057                        NaN                                 NaN
#
#                                       sources deportation decoration_posthume  \
# 0      Service historique de la Défense, Caen           0                   0
# 3      Service historique de la Défense, Caen           0                   0
# 4      Service historique de la Défense, Caen           0                   0
# 5      Service historique de la Défense, Caen           0                   0
# 6      Service historique de la Défense, Caen           0                   0
# ...                                       ...         ...                 ...
# 20052  Service historique de la Défense, Caen           0                   0
# 20053  Service historique de la Défense, Caen           0                   0
# 20054  Service historique de la Défense, Caen           0                   0
# 20056  Service historique de la Défense, Caen           0                   0
# 20057  Service historique de la Défense, Caen           0                   0
#
#       rehabilitation                                     lien_ark_fiche  \
# 0                  0  https://www.memoiredeshommes.sga.defense.gouv....
# 3                  0  https://www.memoiredeshommes.sga.defense.gouv....
# 4                  0  https://www.memoiredeshommes.sga.defense.gouv....
# 5                  0  https://www.memoiredeshommes.sga.defense.gouv....
# 6                  0  https://www.memoiredeshommes.sga.defense.gouv....
# ...              ...                                                ...
# 20052              0  https://www.memoiredeshommes.sga.defense.gouv....
# 20053              0  https://www.memoiredeshommes.sga.defense.gouv....
# 20054              0  https://www.memoiredeshommes.sga.defense.gouv....
# 20056              0  https://www.memoiredeshommes.sga.defense.gouv....
# 20057              0  https://www.memoiredeshommes.sga.defense.gouv....
#
#       corps_retrouve disparition_jour_mois_annee jdd_jour_mois_annee
# 0                  0                         NaN                 NaN
# 3                  0                         NaN                 NaN
# 4                  0                         NaN                 NaN
# 5                  0                         NaN                 NaN
# 6                  0                         NaN                 NaN
# ...              ...                         ...                 ...
# 20052              0                         NaN                 NaN
# 20053              0                         NaN                 NaN
# 20054              0                         NaN                 NaN
# 20056              0                         NaN                 NaN
# 20057              0                         NaN                 NaN
#
# [11770 rows x 51 columns]

# %%
clean2db.deces_jour_mois_annee
# Out:
# 0        1925-10-08
# 3        1923-08-16
# 4        1925-07-03
# 5        1935-03-29
# 6        1926-03-26
#             ...
# 20052    1930-08-31
# 20053    1925-08-17
# 20054    1932-09-08
# 20056    1921-09-14
# 20057    1921-11-02
# Name: deces_jour_mois_annee, Length: 11770, dtype: object

# %%
clean2db['deces_jour_mois_annee'].str.replace("-","").astype(int)
# Out:
# 0        19251008
# 3        19230816
# 4        19250703
# 5        19350329
# 6        19260326
#            ...
# 20052    19300831
# 20053    19250817
# 20054    19320908
# 20056    19210914
# 20057    19211102
# Name: deces_jour_mois_annee, Length: 11770, dtype: int64

# %%
clean2db.__getitem__(  19249999 < clean2db['deces_jour_mois_annee'].str.replace("-","").astype(int) < 19271111)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/41/1r7_f1_93g56d738vfqw0y8m0000gn/T/ipykernel_4523/3276230016.py in <module>
# ----> 1 clean2db.__getitem__(  19249999 < clean2db['deces_jour_mois_annee'].str.replace("-","").astype(int) < 19271111)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1533     @final
#    1534     def __nonzero__(self):
# -> 1535         raise ValueError(
#    1536             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1537             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
clean2db['deces_jour_mois_annee'] = pd.to_datetime(clean2db['deces_jour_mois_annee']).dt.strftime("%Y%m%d")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         try:
# --> 649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1234
# -> 1235         naive = default.replace(**repl)
#    1236
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650         except ValueError as e:
# --> 651             six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     652
#
# ~/opt/anaconda3/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# ParserError: month must be in 1..12: 1929-00-00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         try:
# --> 649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1234
# -> 1235         naive = default.replace(**repl)
#    1236
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# /var/folders/41/1r7_f1_93g56d738vfqw0y8m0000gn/T/ipykernel_4523/948972849.py in <module>
# ----> 1 clean2db['deces_jour_mois_annee'] = pd.to_datetime(clean2db['deces_jour_mois_annee']).dt.strftime("%Y%m%d")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049             result = arg.map(cache_array)
#    1050         else:
# -> 1051             values = convert_listlike(arg._values, format)
#    1052             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400     assert format is None or infer_datetime_format
#     401     utc = tz == "utc"
# --> 402     result, tz_parsed = objects_to_datetime64ns(
#     403         arg,
#     404         dayfirst=dayfirst,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2215             return values.view("i8"), tz_parsed
#    2216         except (ValueError, TypeError):
# -> 2217             raise err
#    2218
#    2219     if tz_parsed is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2197     order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2198     try:
# -> 2199         result, tz_parsed = tslib.array_to_datetime(
#    2200             data.ravel("K"),
#    2201             errors=errors,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/tslib.pyx in pandas._libs.tslib._array_to_datetime_object()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1366         return parser(parserinfo).parse(timestr, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#    1370
#
# ~/opt/anaconda3/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
# --> 651             six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     652
#     653         if not ignoretz:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# ParserError: month must be in 1..12: 1929-00-00
